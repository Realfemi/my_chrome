# %% [markdown]
# <a href="https://colab.research.google.com/github/Realfemi/my_chrome/blob/main/ACME_Happiness_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================
# Step 10: Load Private Test Set & Predict
# =========================================

# Upload private test set
print("\nUpload your private test set CSV (no 'Y' column):")
private_uploaded = files.upload()

# Automatically pick uploaded private test set filename
private_filename = list(private_uploaded.keys())[0]
print("Private test set detected:", private_filename)

# Load private test set
private_df = pd.read_csv(io.BytesIO(private_uploaded[private_filename]))
print("\nFirst 5 rows of private test set:")
print(private_df.head())

# Check if columns match
print("\nColumns in private test set:", private_df.columns.tolist())

# Extract features
X_private = private_df[['X1','X2','X3','X4','X5','X6']]

# Scale features using the scaler from training
X_private_scaled = scaler.transform(X_private)

# ------------------------------
# Step 11: Pick Best Model & Predict
# ------------------------------

# Evaluate which model had highest accuracy on test set
best_model_name = None
best_accuracy = 0
best_model = None

for name, model in models.items():
    y_pred_test = model.predict(X_test_scaled)
    acc = accuracy_score(y_test, y_pred_test)
    if acc > best_accuracy:
        best_accuracy = acc
        best_model_name = name
        best_model = model

print(f"\nBest model based on test accuracy: {best_model_name} ({best_accuracy:.4f})")

# Predict on private test set
private_predictions = best_model.predict(X_private_scaled)
private_df['Y_pred'] = private_predictions

# ------------------------------
# Step 12: Export Predictions
# ------------------------------
output_filename = "ACME_Happiness_Predictions.csv"
private_df.to_csv(output_filename, index=False)
print(f"\nPredictions saved to: {output_filename}")
import pandas as pd
predictions = pd.read_csv("ACME_Happiness_Predictions.csv")
predictions.head()
# Out:
# Upload your private test set CSV (no 'Y' column):
#      <input type="file" id="files-e472aab8-ecdc-4faa-bc8c-a5bef350ef1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e472aab8-ecdc-4faa-bc8c-a5bef350ef1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
